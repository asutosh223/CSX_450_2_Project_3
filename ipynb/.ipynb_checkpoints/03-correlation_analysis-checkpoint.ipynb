# %% [markdown]
# ### Correlation Analysis
# - Check for redundancy in the data.
# - Check for correlation in the data.
# - Prepare a heatmap of correlation and a pairplot of the data.
# - Discuss how the correlation can be seen in the pairplot.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing_df = pd.read_csv('/home/jovyan/UCLA_CSX_450_2_2018_W/Project3_Housing/housing_data.csv',delim_whitespace=True, header=None)
housing_df.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
housing_df.drop(['MEDV'], axis=1, inplace=True)

# %%
housing_df.shape
# Out:
# (506, 13)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
def calculate_r_2_for_feature(data,feature):
    new_data = data.drop(feature, axis=1)

    X_train, \
    X_test,  \
    y_train, \
    y_test = train_test_split(
        new_data,data[feature],test_size=0.25
    )

    regressor = KNeighborsRegressor()
    regressor.fit(X_train,y_train)

    score = regressor.score(X_test,y_test)
    return score

# %%
calculate_r_2_for_feature(housing_df,'CRIM')
# Out:
# 0.27152469328237494

# %%
calculate_r_2_for_feature(housing_df,'CRIM')
# Out:
# 0.20445948714434994

# %%
def mean_r2_for_feature(data, feature):
    scores = []
    for _ in range(100):
        scores.append(calculate_r_2_for_feature(data, feature))
        
    scores = np.array(scores)
    return scores.mean()

# %%
mean_r2_for_feature(housing_df,'CRIM')
# Out:
# 0.34293208682140447

# %%
mean_r2_for_feature(housing_df,'ZN')
# Out:
# 0.45145726466726183

# %%
mean_r2_for_feature(housing_df,'INDUS')
# Out:
# 0.82127183846252139

# %%
mean_r2_for_feature(housing_df,'CHAS')
# Out:
# 0.0079984897849971186

# %%
mean_r2_for_feature(housing_df,'NOX')
# Out:
# 0.75914938149843025

# %%
mean_r2_for_feature(housing_df,'RM')
# Out:
# 0.22159662159423102

# %%
mean_r2_for_feature(housing_df,'AGE')
# Out:
# 0.61194022106452617

# %%
mean_r2_for_feature(housing_df,'DIS')
# Out:
# 0.79890004896344546

# %%
mean_r2_for_feature(housing_df,'RAD')
# Out:
# 0.957111184020215

# %%
mean_r2_for_feature(housing_df,'TAX')
# Out:
# 0.84509420487301734

# %%
mean_r2_for_feature(housing_df,'PTRATIO')
# Out:
# 0.5850566458299713

# %%
mean_r2_for_feature(housing_df,'B')
# Out:
# 0.14601676377479542

# %%
mean_r2_for_feature(housing_df,'LSTAT')
# Out:
# 0.46063542967821797

# %%
import time
start = time.time()
sns.pairplot(housing_df, kind='reg')
print(time.time() - start)
# Out:
# 744.9862277507782

# %%
corr = housing_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, 0)] = True
with sns.axes_style("white"):
    ax = sns.heatmap(corr, mask=mask, square=True, annot=True,
                     cmap='RdBu', fmt='+.3f')
    plt.xticks(rotation=45, ha='center')
